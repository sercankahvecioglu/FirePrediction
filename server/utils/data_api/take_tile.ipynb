# %%
import os 
import pickle
import numpy as np

# %%
FILE_PATH = '/Users/diego/Documents/FirePrediction/server/utils/data_api/data/chile_pre_tile_3_3.pkl'

# %%
# LOAD DATA
with open(FILE_PATH, 'rb') as f:
    data = pickle.load(f)

data
# Out:
# [{'bands.tif': array([[[0.1313, 0.1001, 0.07  , ..., 0.0007, 0.0196, 0.0134],
#           [0.1313, 0.097 , 0.0658, ..., 0.0007, 0.0175, 0.0129],
#           [0.1313, 0.099 , 0.0644, ..., 0.0007, 0.0175, 0.0129],
#           ...,
#           [0.1619, 0.1236, 0.1049, ..., 0.0007, 0.0202, 0.0146],
#           [0.1619, 0.1222, 0.106 , ..., 0.0007, 0.0202, 0.0146],
#           [0.1619, 0.1422, 0.1222, ..., 0.0007, 0.0249, 0.0174]],
#
#          [[0.1313, 0.1016, 0.0707, ..., 0.0007, 0.0196, 0.0134],
#           [0.1313, 0.098 , 0.0663, ..., 0.0007, 0.0175, 0.0129],
#           [0.1313, 0.0997, 0.067 , ..., 0.0007, 0.0175, 0.0129],
#           ...,
#           [0.1619, 0.1175, 0.0981, ..., 0.0007, 0.0202, 0.0146],
#           [0.1619, 0.1205, 0.0988, ..., 0.0007, 0.0202, 0.0146],
#           [0.1619, 0.1294, 0.1157, ..., 0.0007, 0.0249, 0.0174]],
#
#          [[0.1332, 0.1009, 0.071 , ..., 0.0006, 0.0222, 0.0157],
#           [0.1332, 0.0978, 0.0689, ..., 0.0006, 0.0203, 0.0144],
# ...

# %%
image = data[0]['bands.tif']

# %%
# Display the image 

import matplotlib.pyplot as plt

plt.imshow(image[:,:,[3,2,1]])
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0225..1.6248].

# %%
MASK_PATH = '/Users/diego/Documents/FirePrediction/LABEL_chile_tile_(6656, 7168).npy'
data = np.load(MASK_PATH)

# %%
# Display data mask
import matplotlib.pyplot as plt

plt.imshow(data, cmap="coolwarm", interpolation="nearest")
plt.axis('off')
plt.show()
